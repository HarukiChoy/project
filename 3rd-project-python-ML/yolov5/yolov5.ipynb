# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pytorch==1.7.0 torchvision==0.8.0 torchaudio==0.7.0 -c pytorch
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pytorch==1.7.0
#   - torchvision==0.8.0
#   - torchaudio==0.7.0
#
# Current channels:
#
#   - https://conda.anaconda.org/pytorch/osx-arm64
#   - https://conda.anaconda.org/pytorch/noarch
#   - https://conda.anaconda.org/conda-forge/osx-arm64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 train.py --batch 32 --epochs 150 --data 'data/text.yaml' --weights 'yolov5s6.pt' --cache --freeze 12 --project 'text_detection' --name 'feature_extraction'
# Out:
# train: weights=yolov5s6.pt, cfg=, data=data/text.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=text_detection, name=feature_extraction, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[12], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.10.6 torch-1.12.1 CPU
#
# ...

# %%
# !python3 train.py --hyp 'hyp.VOC.yaml' --batch 16 --epochs 100 --data 'data/text.yaml' --weights 'text_detection/feature_extraction2/weights/best.pt' --project 'text_detection' --name 'fine-tuning' --cache
# Out:
# train: weights=text_detection/feature_extraction2/weights/best.pt, cfg=, data=data/text.yaml, hyp=hyp.VOC.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=text_detection, name=fine-tuning, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-206-gfba61e5 Python-3.10.6 torch-1.12.1 CPU
#
# ...

# %%
#!python3 val.py --batch 64 --data 'data/text.yaml' --weights 'text_detection/feature_extraction2/weights/best.pt' --task test --project 'text_detection' --name 'Validation' --augment


# !python3 detect.py --source /Users/sheungpanlo/Desktop/Self_programming/Deep_learning/yolov5/yolov5/uploads/TEST_1516.jpg \
     --weights 'text_detection/feature_extraction2/weights/best.pt' --save-crop
# Out:
# detect: weights=['text_detection/feature_extraction2/weights/best.pt'], source=/Users/sheungpanlo/Desktop/Self_programming/Deep_learning/yolov5/yolov5/uploads/TEST_1516.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-207-g601dec6 Python-3.10.6 torch-1.12.1 CPU
#
# Fusing layers...
# Model summary: 206 layers, 12308200 parameters, 0 gradients, 16.1 GFLOPs
# image 1/1 /Users/sheungpanlo/Desktop/Self_programming/Deep_learning/yolov5/yolov5/uploads/TEST_1516.jpg: 128x640 10 Texts, 32.2ms
# Speed: 0.5ms pre-process, 32.2ms inference, 5.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !python3 val.py --batch 64 --data 'data/text.yaml' --weights 'text_detection/fine-tuning2/weights/best.pt' --task test --project 'text_detection' --name 'Validation' --augment
# Out:
# val: data=data/text.yaml, weights=['text_detection/fine-tuning2/weights/best.pt'], batch_size=64, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=text_detection, name=Validation, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-206-gfba61e5 Python-3.10.6 torch-1.12.1 CPU
#
# Fusing layers...
# Model summary: 206 layers, 12308200 parameters, 0 gradients, 16.1 GFLOPs
# test: Scanning '/Users/sheungpanlo/Desktop/Self_programming/Deep_learning/yolov5
#                  Class     Images  Instances          P          R      mAP50
#                    all         29          0          0          0          0          0
# WARNING ⚠️ no labels found in test set, can not compute metrics without labels
# Speed: 0.5ms pre-process, 399.5ms inference, 0.7ms NMS per image at shape (64, 3, 640, 640)
# ...
